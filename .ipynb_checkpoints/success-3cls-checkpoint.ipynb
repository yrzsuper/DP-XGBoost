# %%
import numpy as np
import dpxgboost as xgb
from matplotlib import pyplot as plt
import argparse

import pandas as pd

from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Out:
# ======== ['/Users/yangchengyi/Downloads/myCode/src/dpxgboost/lib/libxgboost.dylib']
# ======== /Users/yangchengyi/opt/anaconda3/bin:/Users/yangchengyi/opt/anaconda3/condabin:/Library/Frameworks/Python.framework/Versions/2.7/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/TeX/texbin:/usr/local/go/bin:/opt/X11/bin:/Library/Apple/usr/bin:/Users/yangchengyi/Downloads/myCode/src/dpxgboost/lib
# ======== <CDLL '/Users/yangchengyi/Downloads/myCode/src/dpxgboost/lib/libxgboost.dylib', handle 206a3f8e0 at 0x7fada812bb20>

# %%
LD = pd.read_excel('dataset/soybean_data.xlsx', sheet_name = 0, index_col="Unnamed: 0")
LQ = pd.read_excel('dataset/soybean_data.xlsx', sheet_name = 1, index_col="Unnamed: 0")
LY = pd.read_excel('dataset/soybean_data.xlsx', sheet_name = 2, index_col="Unnamed: 0")
#QJ = pd.read_excel('dataset/soybean_data.xlsx', sheet_name = 3, index_col="Unnamed: 0")

# %%
LD
# Out:
#                10995.440  10992.580  10989.730  10986.880  10984.030  \
# LD18-54-5-1     0.293637   0.345386   0.367405   0.353483   0.332818
# LD18-54-5-2     0.273260   0.297736   0.344296   0.366579   0.351957
# LD18-54-5-3     0.176623   0.210188   0.262520   0.295643   0.297286
# LD18-54-5-4     0.233919   0.291226   0.380982   0.431118   0.414464
# LD18-54-5-5     0.301912   0.331431   0.359882   0.368183   0.366175
# ...                  ...        ...        ...        ...        ...
# LD18-54-100-5   0.251875   0.248502   0.276904   0.316206   0.346754
# LD18-54-100-6   0.328291   0.312754   0.325412   0.346807   0.360035
# LD18-54-100-7   0.363638   0.375104   0.382260   0.371123   0.331500
# LD18-54-100-8   0.384589   0.443209   0.472618   0.450951   0.413820
# LD18-54-100-9   0.303011   0.358918   0.405759   0.408437   0.370158
#
#                10981.170  10978.320  10975.470  10972.620  10969.770  ...  \
# LD18-54-5-1     0.317063   0.308321   0.322031   0.358805   0.378637  ...
# LD18-54-5-2     0.324675   0.308249   0.316360   0.334786   0.331465  ...
# LD18-54-5-3     0.284267   0.278091   0.281799   0.273696   0.240368  ...
# LD18-54-5-4     0.365552   0.324812   0.313450   0.327986   0.349369  ...
# LD18-54-5-5     0.356401   0.327788   0.297478   0.282435   0.272669  ...
# ...                  ...        ...        ...        ...        ...  ...
# LD18-54-100-5   0.356350   0.343214   0.323082   0.313461   0.311370  ...
# LD18-54-100-6   0.348475   0.301915   0.246370   0.217210   0.220771  ...
# LD18-54-100-7   0.280229   0.249879   0.253253   0.268696   0.271664  ...
# LD18-54-100-8   0.389722   0.386492   0.407619   0.433930   0.417750  ...
# LD18-54-100-9   0.314783   0.278960   0.295652   0.353782   0.390565  ...
#
#                4024.529   4021.676   4018.824   4015.972   4013.120   \
# LD18-54-5-1     1.337818   1.338347   1.338074   1.337426   1.336938
# LD18-54-5-2     1.354339   1.355796   1.357007   1.357882   1.358525
# LD18-54-5-3     1.352859   1.353792   1.353951   1.353440   1.353156
# LD18-54-5-4     1.347638   1.347293   1.347413   1.347813   1.348120
# LD18-54-5-5     1.362457   1.362269   1.361881   1.361440   1.361134
# ...                  ...        ...        ...        ...        ...
# LD18-54-100-5   1.375933   1.375844   1.375728   1.375638   1.375798
# LD18-54-100-6   1.380620   1.380951   1.381425   1.381830   1.381968
# LD18-54-100-7   1.377126   1.376103   1.375259   1.375094   1.375593
# LD18-54-100-8   1.388343   1.388425   1.388490   1.388535   1.388947
# LD18-54-100-9   1.371614   1.371060   1.371902   1.373974   1.375964
#
#                4010.268   4007.415   4004.563   4001.711   3998.858
# LD18-54-5-1     1.336941   1.337450   1.338249   1.339122   1.339906
# LD18-54-5-2     1.359029   1.359558   1.360356   1.361438   1.362291
# LD18-54-5-3     1.353581   1.354289   1.354846   1.355258   1.355397
# LD18-54-5-4     1.348358   1.348744   1.349305   1.349988   1.350742
# LD18-54-5-5     1.361147   1.361629   1.362615   1.363992   1.365531
# ...                  ...        ...        ...        ...        ...
# LD18-54-100-5   1.376244   1.376548   1.376280   1.375693   1.375517
# LD18-54-100-6   1.381916   1.381928   1.382092   1.382358   1.382735
# LD18-54-100-7   1.376532   1.377630   1.378405   1.378399   1.377743
# LD18-54-100-8   1.389847   1.390607   1.390633   1.390257   1.390297
# LD18-54-100-9   1.376596   1.375866   1.375009   1.375112   1.376002
#
# [96 rows x 2454 columns]

# %%
soy_data = pd.concat([LD, LQ, LY],axis=0,sort=False)

# %%
soy_data
# Out:
#                 10995.440  10992.580  10989.730  10986.880  10984.030  \
# LD18-54-5-1      0.293637   0.345386   0.367405   0.353483   0.332818
# LD18-54-5-2      0.273260   0.297736   0.344296   0.366579   0.351957
# LD18-54-5-3      0.176623   0.210188   0.262520   0.295643   0.297286
# LD18-54-5-4      0.233919   0.291226   0.380982   0.431118   0.414464
# LD18-54-5-5      0.301912   0.331431   0.359882   0.368183   0.366175
# ...                   ...        ...        ...        ...        ...
# LY16-54-100-6    0.413203   0.412709   0.410091   0.411389   0.419425
# LY16-54-100-7    0.313963   0.329563   0.336978   0.343901   0.364007
# LY16-54-100-8    0.323247   0.338544   0.360113   0.366485   0.355808
# LY16-54-100-9    0.445155   0.449665   0.440161   0.446256   0.476969
# LY16-54-100-10   0.383663   0.372315   0.350311   0.340593   0.353056
#
#                 10981.170  10978.320  10975.470  10972.620  10969.770  ...  \
# LD18-54-5-1      0.317063   0.308321   0.322031   0.358805   0.378637  ...
# LD18-54-5-2      0.324675   0.308249   0.316360   0.334786   0.331465  ...
# LD18-54-5-3      0.284267   0.278091   0.281799   0.273696   0.240368  ...
# LD18-54-5-4      0.365552   0.324812   0.313450   0.327986   0.349369  ...
# LD18-54-5-5      0.356401   0.327788   0.297478   0.282435   0.272669  ...
# ...                   ...        ...        ...        ...        ...  ...
# LY16-54-100-6    0.418556   0.398198   0.364432   0.330510   0.314765  ...
# LY16-54-100-7    0.394706   0.413154   0.398632   0.359094   0.332024  ...
# LY16-54-100-8    0.347094   0.345525   0.339544   0.329567   0.337898  ...
# LY16-54-100-9    0.517699   0.554598   0.569118   0.533821   0.449128  ...
# LY16-54-100-10   0.380406   0.399968   0.402498   0.403866   0.426297  ...
#
#                 4024.529   4021.676   4018.824   4015.972   4013.120   \
# LD18-54-5-1      1.337818   1.338347   1.338074   1.337426   1.336938
# LD18-54-5-2      1.354339   1.355796   1.357007   1.357882   1.358525
# LD18-54-5-3      1.352859   1.353792   1.353951   1.353440   1.353156
# LD18-54-5-4      1.347638   1.347293   1.347413   1.347813   1.348120
# LD18-54-5-5      1.362457   1.362269   1.361881   1.361440   1.361134
# ...                   ...        ...        ...        ...        ...
# LY16-54-100-6    1.435558   1.436222   1.436731   1.437057   1.437105
# LY16-54-100-7    1.440521   1.441682   1.442262   1.442013   1.441623
# LY16-54-100-8    1.441643   1.442681   1.443749   1.444302   1.444200
# LY16-54-100-9    1.438716   1.439136   1.439757   1.440553   1.441180
# LY16-54-100-10   1.429125   1.430020   1.430974   1.431481   1.431774
#
#                 4010.268   4007.415   4004.563   4001.711   3998.858
# LD18-54-5-1      1.336941   1.337450   1.338249   1.339122   1.339906
# LD18-54-5-2      1.359029   1.359558   1.360356   1.361438   1.362291
# LD18-54-5-3      1.353581   1.354289   1.354846   1.355258   1.355397
# LD18-54-5-4      1.348358   1.348744   1.349305   1.349988   1.350742
# LD18-54-5-5      1.361147   1.361629   1.362615   1.363992   1.365531
# ...                   ...        ...        ...        ...        ...
# LY16-54-100-6    1.436602   1.435493   1.434473   1.434517   1.435750
# LY16-54-100-7    1.441599   1.441693   1.441574   1.441374   1.441386
# LY16-54-100-8    1.443692   1.443092   1.442613   1.442492   1.442960
# LY16-54-100-9    1.441347   1.441289   1.441401   1.441688   1.441942
# LY16-54-100-10   1.432247   1.432777   1.433050   1.433160   1.433336
#
# [308 rows x 2454 columns]

# %%
labels_list = soy_data.index
prefix_labels_list = []
for name in labels_list:
    tmp_name = ""
    for token in name:
        if token.isalpha():
            tmp_name += token
    prefix_labels_list.append(tmp_name)
len(prefix_labels_list)
# Out:
# 308

# %%
labels_counts_dict = dict()
for name in prefix_labels_list:
    if name in labels_counts_dict:
        labels_counts_dict[name] += 1
    else:
        labels_counts_dict[name] = 1
print(labels_counts_dict)
# Out:
# {'LD': 96, 'LQ': 101, 'LY': 111}

# %%
soy_data.index = prefix_labels_list

# %%
soy_data
# Out:
#     10995.440  10992.580  10989.730  10986.880  10984.030  10981.170  \
# LD   0.293637   0.345386   0.367405   0.353483   0.332818   0.317063
# LD   0.273260   0.297736   0.344296   0.366579   0.351957   0.324675
# LD   0.176623   0.210188   0.262520   0.295643   0.297286   0.284267
# LD   0.233919   0.291226   0.380982   0.431118   0.414464   0.365552
# LD   0.301912   0.331431   0.359882   0.368183   0.366175   0.356401
# ..        ...        ...        ...        ...        ...        ...
# LY   0.413203   0.412709   0.410091   0.411389   0.419425   0.418556
# LY   0.313963   0.329563   0.336978   0.343901   0.364007   0.394706
# LY   0.323247   0.338544   0.360113   0.366485   0.355808   0.347094
# LY   0.445155   0.449665   0.440161   0.446256   0.476969   0.517699
# LY   0.383663   0.372315   0.350311   0.340593   0.353056   0.380406
#
#     10978.320  10975.470  10972.620  10969.770  ...  4024.529   4021.676   \
# LD   0.308321   0.322031   0.358805   0.378637  ...   1.337818   1.338347
# LD   0.308249   0.316360   0.334786   0.331465  ...   1.354339   1.355796
# LD   0.278091   0.281799   0.273696   0.240368  ...   1.352859   1.353792
# LD   0.324812   0.313450   0.327986   0.349369  ...   1.347638   1.347293
# LD   0.327788   0.297478   0.282435   0.272669  ...   1.362457   1.362269
# ..        ...        ...        ...        ...  ...        ...        ...
# LY   0.398198   0.364432   0.330510   0.314765  ...   1.435558   1.436222
# LY   0.413154   0.398632   0.359094   0.332024  ...   1.440521   1.441682
# LY   0.345525   0.339544   0.329567   0.337898  ...   1.441643   1.442681
# LY   0.554598   0.569118   0.533821   0.449128  ...   1.438716   1.439136
# LY   0.399968   0.402498   0.403866   0.426297  ...   1.429125   1.430020
#
#     4018.824   4015.972   4013.120   4010.268   4007.415   4004.563   \
# LD   1.338074   1.337426   1.336938   1.336941   1.337450   1.338249
# LD   1.357007   1.357882   1.358525   1.359029   1.359558   1.360356
# LD   1.353951   1.353440   1.353156   1.353581   1.354289   1.354846
# LD   1.347413   1.347813   1.348120   1.348358   1.348744   1.349305
# LD   1.361881   1.361440   1.361134   1.361147   1.361629   1.362615
# ..        ...        ...        ...        ...        ...        ...
# LY   1.436731   1.437057   1.437105   1.436602   1.435493   1.434473
# LY   1.442262   1.442013   1.441623   1.441599   1.441693   1.441574
# LY   1.443749   1.444302   1.444200   1.443692   1.443092   1.442613
# LY   1.439757   1.440553   1.441180   1.441347   1.441289   1.441401
# LY   1.430974   1.431481   1.431774   1.432247   1.432777   1.433050
#
#     4001.711   3998.858
# LD   1.339122   1.339906
# LD   1.361438   1.362291
# LD   1.355258   1.355397
# LD   1.349988   1.350742
# LD   1.363992   1.365531
# ..        ...        ...
# LY   1.434517   1.435750
# LY   1.441374   1.441386
# LY   1.442492   1.442960
# LY   1.441688   1.441942
# LY   1.433160   1.433336
#
# [308 rows x 2454 columns]

# %%
features = soy_data
del soy_data

# %%
features = features.fillna(features.mean())

# %%
features.index
# Out:
# Index(['LD', 'LD', 'LD', 'LD', 'LD', 'LD', 'LD', 'LD', 'LD', 'LD',
#        ...
#        'LY', 'LY', 'LY', 'LY', 'LY', 'LY', 'LY', 'LY', 'LY', 'LY'],
#       dtype='object', length=308)

# %%
char2num_dict = dict()
num = 0
for key in labels_counts_dict:
    char2num_dict[key] = num
    num += 1
del num

# %%
char2num_dict
# Out:
# {'LD': 0, 'LQ': 1, 'LY': 2}

# %%
labels = []
for i in features.index:
    labels.append(char2num_dict[i])

# %%
features = np.array(features)
labels = np.array(labels)

# %%
features = normalize(X = features, axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    features, labels, test_size = 0.2
)

# %%
kRows = 246
kCols = 2454
kClasses = 3                    # number of classes

kRounds = 100                    # number of boosting rounds.


m = xgb.DMatrix(X_train, y_train)

# %%
features.shape
# Out:
# (308, 2454)

# %%
def softmax(x):
    '''Softmax function with x as input vector.'''
    e = np.exp(x)
    return e / np.sum(e)


def softprob_obj(predt: np.ndarray, data: xgb.DMatrix):
    '''Loss function.  Computing the gradient and approximated hessian (diagonal).
    Reimplements the `multi:softprob` inside XGBoost.

    '''
#     print('======data======',print(data))
    
    labels = data.get_label()
    if data.get_weight().size == 0:
        # Use 1 as weight if we don't have custom weight.
        weights = np.ones((kRows, 1), dtype=float)
    else:
        weights = data.get_weight()

    # The prediction is of shape (rows, classes), each element in a row
    # represents a raw prediction (leaf weight, hasn't gone through softmax
    # yet).  In XGBoost 1.0.0, the prediction is transformed by a softmax
    # function, fixed in later versions.
    
#     print("predt.shape", predt.shape )
#     print("(kRows, kClasses)", (kRows, kClasses))
    
    assert predt.shape == (kRows, kClasses)

    grad = np.zeros((kRows, kClasses), dtype=float)
    hess = np.zeros((kRows, kClasses), dtype=float)
    

    eps = 1e-6

    # compute the gradient and hessian, slow iterations in Python, only
    # suitable for demo.  Also the one in native XGBoost core is more robust to
    # numeric overflow as we don't do anything to mitigate the `exp` in
    # `softmax` here.
    for r in range(predt.shape[0]):
        target = labels[r]
        p = softmax(predt[r, :])
        for c in range(predt.shape[1]):
            assert target >= 0 or target <= kClasses
            g = p[c] - 1.0 if c == target else p[c]
            g = g * weights[r]
            h = max((2.0 * p[c] * (1.0 - p[c]) * weights[r]).item(), eps)
            grad[r, c] = g
            hess[r, c] = h
    
    # Right now (XGBoost 1.0.0), reshaping is necessary
    grad = grad.reshape((kRows * kClasses, 1))  
    hess = hess.reshape((kRows * kClasses, 1))
    
    
    grad = grad + np.random.normal(loc=0,scale=0.002,size=grad.shape)
    hess = hess + np.random.normal(loc=0,scale=0.002,size=grad.shape)
    
    print("##########")
    
    return grad, hess

# %%
def predict(booster: xgb.Booster, X):
    '''A customized prediction function that converts raw prediction to
    target class.

    '''
    # Output margin means we want to obtain the raw prediction obtained from
    # tree leaf weight.
    predt = booster.predict(X, output_margin=True)
    out = np.zeros(kRows)
    for r in range(predt.shape[0]):
        # the class with maximum prob (not strictly prob as it haven't gone
        # through softmax yet so it doesn't sum to 1, but result is the same
        # for argmax).
        i = np.argmax(predt[r])
        out[r] = i
    return out


def merror(predt: np.ndarray, dtrain: xgb.DMatrix):
    y = dtrain.get_label()
    # Like custom objective, the predt is untransformed leaf weight when custom objective
    # is provided.

    # With the use of `custom_metric` parameter in train function, custom metric receives
    # raw input only when custom objective is also being used.  Otherwise custom metric
    # will receive transformed prediction.
    assert predt.shape == (kRows, kClasses)
    out = np.zeros(kRows)
    for r in range(predt.shape[0]):
        i = np.argmax(predt[r])
        out[r] = i

    assert y.shape == out.shape

    errors = np.zeros(kRows)
    errors[y != out] = 1.0
    return 'PyMError', np.sum(errors) / kRows

# %%
del m

# %%
m = xgb.DMatrix(X_train, y_train)

# %%
custom_results = {}
booster_custom = xgb.train({'num_class': kClasses,
                                'disable_default_eval_metric': True},
                               m,
                               num_boost_round=kRounds,
                               obj=softprob_obj,
                               custom_metric=merror,
                               evals_result=custom_results,
                               evals=[(m, 'train')])

predt_custom = predict(booster_custom, m)
# Out:
# ##########
# [0]	train-PyMError:0.00000
# ##########
# [1]	train-PyMError:0.00000
# ##########
# [2]	train-PyMError:0.00000
# ##########
# [3]	train-PyMError:0.00000
# ##########
# [4]	train-PyMError:0.00000
# ##########
# [5]	train-PyMError:0.00000
# ##########
# [6]	train-PyMError:0.00000
# ##########
# [7]	train-PyMError:0.00000
# ##########
# [8]	train-PyMError:0.00000
# ##########
# [9]	train-PyMError:0.00000
# ##########
# [10]	train-PyMError:0.00000
# ##########
# [11]	train-PyMError:0.00000
# ##########
# [12]	train-PyMError:0.00000
# ##########
# [13]	train-PyMError:0.00000
# ##########
# [14]	train-PyMError:0.00000
# ##########
# [15]	train-PyMError:0.00000
# ##########
# [16]	train-PyMError:0.00000
# ##########
# [17]	train-PyMError:0.00000
# ##########
# [18]	train-PyMError:0.00000
# ##########
# [19]	train-PyMError:0.00000
# ##########
# [20]	train-PyMError:0.00000
# ##########
# [21]	train-PyMError:0.00000
# ##########
# [22]	train-PyMError:0.00000
# ##########
# [23]	train-PyMError:0.00000
# ##########
# [24]	train-PyMError:0.00000
# ##########
# [25]	train-PyMError:0.00000
# ##########
# [26]	train-PyMError:0.00000
# ##########
# [27]	train-PyMError:0.00000
# ##########
# [28]	train-PyMError:0.00000
# ##########
# [29]	train-PyMError:0.00000
# ##########
# [30]	train-PyMError:0.00000
# ##########
# [31]	train-PyMError:0.00000
# ##########
# [32]	train-PyMError:0.00000
# ##########
# [33]	train-PyMError:0.00000
# ##########
# [34]	train-PyMError:0.00000
# ##########
# [35]	train-PyMError:0.00000
# ##########
# [36]	train-PyMError:0.00000
# ##########
# [37]	train-PyMError:0.00000
# ##########
# [38]	train-PyMError:0.00000
# ##########
# [39]	train-PyMError:0.00000
# ##########
# [40]	train-PyMError:0.00000
# ##########
# [41]	train-PyMError:0.00000
# ##########
# [42]	train-PyMError:0.00000
# ##########
# [43]	train-PyMError:0.00000
# ##########
# [44]	train-PyMError:0.00000
# ##########
# [45]	train-PyMError:0.00000
# ##########
# [46]	train-PyMError:0.00000
# ##########
# [47]	train-PyMError:0.00000
# ##########
# [48]	train-PyMError:0.00000
# ##########
# [49]	train-PyMError:0.00000
# ##########
# [50]	train-PyMError:0.00000
# ##########
# [51]	train-PyMError:0.00000
# ##########
# [52]	train-PyMError:0.00000
# ##########
# [53]	train-PyMError:0.00000
# ##########
# [54]	train-PyMError:0.00000
# ##########
# [55]	train-PyMError:0.00000
# ##########
# [56]	train-PyMError:0.00000
# ##########
# [57]	train-PyMError:0.00000
# ##########
# [58]	train-PyMError:0.00000
# ##########
# [59]	train-PyMError:0.00000
# ##########
# [60]	train-PyMError:0.00000
# ##########
# [61]	train-PyMError:0.00000
# ##########
# [62]	train-PyMError:0.00000
# ##########
# [63]	train-PyMError:0.00000
# ##########
# [64]	train-PyMError:0.00000
# ##########
# [65]	train-PyMError:0.00000
# ##########
# [66]	train-PyMError:0.00000
# ##########
# [67]	train-PyMError:0.00000
# ##########
# [68]	train-PyMError:0.00000
# ##########
# [69]	train-PyMError:0.00000
# ##########
# [70]	train-PyMError:0.00000
# ##########
# [71]	train-PyMError:0.00000
# ##########
# [72]	train-PyMError:0.00000
# ##########
# [73]	train-PyMError:0.00000
# ##########
# [74]	train-PyMError:0.00000
# ##########
# [75]	train-PyMError:0.00000
# ##########
# [76]	train-PyMError:0.00000
# ##########
# [77]	train-PyMError:0.00000
# ##########
# [78]	train-PyMError:0.00000
# ##########
# [79]	train-PyMError:0.00000
# ##########
# [80]	train-PyMError:0.00000
# ##########
# [81]	train-PyMError:0.00000
# ##########
# [82]	train-PyMError:0.00000
# ##########
# [83]	train-PyMError:0.00000
# ##########
# [84]	train-PyMError:0.00000
# ##########
# [85]	train-PyMError:0.00000
# ##########
# [86]	train-PyMError:0.00000
# ##########
# [87]	train-PyMError:0.00000
# ##########
# [88]	train-PyMError:0.00000
# ##########
# [89]	train-PyMError:0.00000
# ##########
# [90]	train-PyMError:0.00000
# ##########
# [91]	train-PyMError:0.00000
# ##########
# [92]	train-PyMError:0.00000
# ##########
# [93]	train-PyMError:0.00000
# ##########
# [94]	train-PyMError:0.00000
# ##########
# [95]	train-PyMError:0.00000
# ##########
# [96]	train-PyMError:0.00000
# ##########
# [97]	train-PyMError:0.00000
# ##########
# [98]	train-PyMError:0.00000
# ##########
# [99]	train-PyMError:0.00000
